# %% [markdown]
# ### **Ejemplos para pasar a UTC**

# %%
# from datetime import datetime, timedelta

# t0 = datetime(2029, 4, 13, 0, 0, 0)
# t1 = t0 + timedelta(days=2, hours=3)
# dt = t1 - t0
# print(t1, dt.total_seconds())

# # 2) pandas (series y rangos)
# import pandas as pd

# t0 = pd.Timestamp("2029-04-13 00:00:00")
# t1 = t0 + pd.Timedelta(days=2, hours=3)
# print(t1, (t1 - t0).total_seconds())
# rng = pd.date_range(t0, periods=5, freq="6h")
# print(rng)

# # 3) astropy (astronomía)
# from astropy.time import Time
# import astropy.units as u

# t0 = Time("2029-04-13 00:00:00", scale="utc")
# t1 = t0 + 2 * u.day + 3 * u.hour
# dt = t1 - t0
# print(t1.isot, dt.to(u.s))
